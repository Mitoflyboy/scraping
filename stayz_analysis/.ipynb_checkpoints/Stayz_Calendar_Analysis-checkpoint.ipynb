# %%
import pandas as pd

# %%
js = pd.read_json('/Users/taj/GitHub/scraping/chrome_stayz_calendar/WebData/stayz_calendar2018-02-23.json',convert_dates=True)

js.head()
# Out:
#                                             calendar              ext_at  \
# 0  <thead><tr><th scope="col"><span title="Monday... 2018-02-23 07:00:14
# 1  <thead><tr><th scope="col"><span title="Monday... 2018-02-23 07:00:16
# 2  <thead><tr><th scope="col"><span title="Monday... 2018-02-23 07:00:19
# 3  <thead><tr><th scope="col"><span title="Monday... 2018-02-23 07:00:20
# 4  <thead><tr><th scope="col"><span title="Monday... 2018-02-23 07:00:23
#
#   property_id  review_count  review_value
# 0     9153367            38           4.7
# 1     9076897            28           4.6
# 2     9123458            71           4.9
# 3     9114125            27           4.4
# 4     9063683            30           4.9

# %%
js.describe()
# Out:
#        review_count  review_value
# count  18015.000000  18015.000000
# mean       5.296253      1.968726
# std       12.619430      2.800358
# min       -1.000000     -1.000000
# 25%       -1.000000     -1.000000
# 50%        1.000000      3.500000
# 75%        5.000000      4.800000
# max      192.000000      5.000000

# %%
js.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18015 entries, 0 to 18014
# Data columns (total 5 columns):
# calendar        18015 non-null object
# ext_at          18015 non-null datetime64[ns]
# property_id     18015 non-null object
# review_count    18015 non-null int64
# review_value    18015 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 844.5+ KB

# %%
#cal_data = js['calendar']

# %%
import datetime
import re
import lxml
from bs4 import BeautifulSoup
import json
#import bs4 as BeautifulSoup
from calendar import monthrange

d = datetime.date.today()
mr = monthrange(d.year, d.month )
cur_month = d.month


fp = open('/Users/taj/GitHub/scraping/chrome_stayz_calendar/WebData/stayz__processed_calendar' + datetime.datetime.now().strftime("%Y-%m-%d") + '.json', 'w')


    
#for index, row in js.iloc[0]:
for i in range(0,1):
    
    
    all_months = {}
    
    cur_month = d.month
    
    row = js.iloc[0]
    
    #print("Raw calendar: ")
    #print(row['calendar'])

    # Set all the six months
    for i in range(cur_month,cur_month+6):

        mr = monthrange( d.year, i )

        max_day = mr[1]

        all_months[i] = dict.fromkeys(range(1,max_day+1),'')

        
    raw_cal = "<html><body>" + row['calendar'] + "</body></html>"
    
    soup = BeautifulSoup(raw_cal, 'lxml') # Parse the HTML as a string
    soup_tables = soup.find_all('tbody')# Grab the first table

    for month_tb in soup_tables:

        # Get all the table cells
        td = re.findall('(\<td class=.*\>\w*)', str(month_tb))
        
        print(td)

        for t in td:
            soup = BeautifulSoup(t, 'lxml')

            try:
                day_val = int(soup.text)
                print("Day value: " + str(day_val))

                # If its an unavailable date then mark: 
                m = re.search('c-calendar--unavailable', t)

                if m is not None:
                    all_months[cur_month][day_val] = 'UVL' # Unavailable day

                # If its an unavailable date then mark: 
                m = re.search('c-calendar--arrival-day', t)

                if m is not None:
                    all_months[cur_month][day_val] = 'ARR' # Arrival day

                # If its an unavailable date then mark: 
                m = re.search('c-calendar--departure-day', t)

                if m is not None:
                    all_months[cur_month][day_val] = 'DEP' # Departure day

                m = re.search('c-calendar--available', t)
                
                if m is not None:
                    all_months[cur_month][day_val] = 'AVL' # Available day


            except ValueError:
                day_val = None

        # Move to the next month
        cur_month += 1

    # Print the table to check
    #print(all_months)
    #print(all_months)
    
    cal_details = {}
    cal_details['property_id'] = row['property_id']
    cal_details['calendar'] = all_months
    
    # Write the data to JSON
    json.dump(cal_details, fp)
    fp.write('\n,')
# Out:
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">1</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">2</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">3</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">4</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">5</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">6</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">7</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">8</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">9</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">10</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">11</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">12</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">13</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">14</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">15</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">16</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">17</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">18</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">19</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">20</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">21</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--available"><span class="ui-state-default">22</span></td><td class=" ui-datepicker-days-cell-over c-calendar--arrival-day ui-datepicker-current-day ui-datepicker-today" data-event="click" data-handler="selectDay" data-month="1" data-year="2018"><a class="ui-state-default ui-state-highlight ui-state-active ui-state-hover" href="#">23</a></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">24</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="1" data-year="2018"><a class="ui-state-default" href="#">25</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="1" data-year="2018"><a class="ui-state-default" href="#">26</a></td><td class=" c-calendar- ...
# Day value: 12345678910111213141516171819202122232425262728
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">1</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">2</a></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">3</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">4</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">5</span></td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">6</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">7</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">8</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">9</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">10</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">11</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">12</span></td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">13</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">14</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">15</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">16</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">17</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">18</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">19</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">20</span></td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">21</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class="ui-state-default" href="#">22</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">23</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">24</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="2" data-year="2018"><a class=" ...
# Day value: 12345678910111213141516171819202122232425262728293031
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-week-end ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">1</span></td></tr><tr><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">2</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">3</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">4</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">5</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">6</a></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">7</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">8</span></td></tr><tr><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">9</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">10</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">11</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">12</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">13</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">14</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">15</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">16</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">17</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">18</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">19</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">20</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="3" data-year="2018"><a class="ui-state-default" href="#">21</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-eve ...
# Day value: 123456789101112131415161718192021222324252627282930
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">1</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">2</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">3</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">4</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">5</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">6</span></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">7</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">8</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">9</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">10</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">11</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">12</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">13</a></td></tr><tr><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">14</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">15</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">16</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">17</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">18</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">19</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">20</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">21</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">22</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">23</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">24</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">25</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">26</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="4" data-year="2018"><a class="ui-state-default" href="#">27</a></td></ ...
# Day value: 12345678910111213141516171819202122232425262728293031
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">1</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">2</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">3</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">4</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">5</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">6</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">7</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">8</a></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">9</span></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">10</span></td></tr><tr><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">11</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">12</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">13</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">14</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">15</a></td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">16</span></td><td class=" ui-datepicker-week-end c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">17</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">18</a></td><td class=" c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">19</a></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">20</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">21</span></td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="5" data-year="2018"><a class="ui-state-default" href="#">22</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month=" ...
# Day value: 123456789101112131415161718192021222324252627282930
# ['<td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-week-end ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled">\xa0</td><td class=" ui-datepicker-week-end ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">1</span></td></tr><tr><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">2</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">3</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">4</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">5</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">6</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">7</a></td><td class=" ui-datepicker-week-end c-calendar--arrival-day" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">8</a></td></tr><tr><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">9</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">10</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">11</span></td><td class=" ui-datepicker-unselectable ui-state-disabled c-calendar--unavailable"><span class="ui-state-default">12</span></td><td class=" c-calendar--departure-day" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">13</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">14</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">15</a></td></tr><tr><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">16</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">17</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">18</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">19</a></td><td class=" c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">20</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="click" data-handler="selectDay" data-month="6" data-year="2018"><a class="ui-state-default" href="#">21</a></td><td class=" ui-datepicker-week-end c-calendar--available" data-event="cl ...
# Day value: 12345678910111213141516171819202122232425262728293031
