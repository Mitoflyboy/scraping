# %%
import requests
import pandas as pd
import datetime
import os
import json

# %%
def reverse_geocode(property_id, latitude, longitude):

    
    google_api_key = 'AIzaSyCkaDzkajfpRNU9yVPbs074RbDpVst0V7w'

    # Google Reverse Geocoder API
    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}&key={gkey}".format(
        lat=latitude,
        lon=longitude,
        gkey=google_api_key
    )
    url = "{base}{params}".format(base=base, params=params)
    
    response = requests.get(url)
    
    res = response.json()
    
    # Google formatted address
    add_formatted = res['results'][0]['formatted_address']

    # Google address components
    add_comp = res['results'][0]['address_components']

    # Default values
    st_name = ''
    st_number = ''
    suburb = ''
    council = ''
    state = ''
    postcode = ''
    
    for ac in add_comp:
        
        comp_types = ac['types']
        
        if 'route' in comp_types:
            st_name = ac['short_name']
        elif 'locality' in comp_types:
            suburb = ac['short_name']
        elif 'administrative_area_level_2' in comp_types:
            council = ac['short_name']
        elif 'administrative_area_level_1' in comp_types:
            state = ac['short_name']
        elif 'street_number' in comp_types:
            st_number = ac['short_name']
        elif 'postal_code' in comp_types:
            postcode = ac['short_name']
    
    geo_add = {
        'property_id': property_id
        ,'formatted_address':add_formatted
        ,'st_nbr': st_number
        ,'st_name': st_name
        ,'suburb': suburb
        ,'council': council
        ,'state': state
        ,'postcode': postcode
    }
    
    return geo_add

# %%
reverse_geocode(123456,-33.937401,151.134129)
# Out:
# {'council': 'Rockdale',
#  'formatted_address': '4A East St, Bardwell Valley NSW 2207, Australia',
#  'postcode': '2207',
#  'property_id': 123456,
#  'st_name': 'East St',
#  'st_nbr': '4A',
#  'state': 'NSW',
#  'suburb': 'Bardwell Valley'}

# %%
date_str = datetime.datetime.now().strftime("%Y-%m-%d")

st_list = pd.read_json('/Users/taj/GitHub/scraping/stayz_analysis/WebData/stayz_nsw_extract_' + date_str + '.json')

# Index on property_id
st_list = st_list.reset_index(drop=True)
st_list = st_list.set_index('property_id')


fp = open('/Users/taj/GitHub/scraping/chrome_stayz_calendar/WebData/stayz_geocoded_' + date_str + '.json', 'w')

first_page = True

for p_id, property_data in st_list.iterrows():
    
    print("Property_ID: " + str(p_id))
    plat = property_data['lat'] 
    plon = property_data['lng']
    
    geo_add = reverse_geocode(p_id,plat,plon)
    
    if first_page is True:
        fp.write('[\n')
        first_page = False
    else:
        fp.write('\n,')
    
    # Write the data to JSON
    json.dump(geo_add, fp)   

# Close out the JSON format
fp.write('\n]')    

fp.close()
# Out:
# Property_ID: 9080772
# Property_ID: 9117434
# Property_ID: 9069770
# Property_ID: 9071475
# Property_ID: 9006125
# Property_ID: 9195589
# Property_ID: 9167523
# Property_ID: 9151070
# Property_ID: 9016485
# Property_ID: 9185654
# Property_ID: 9007287
# Property_ID: 9082905
# Property_ID: 9179007
# Property_ID: 9162472
# Property_ID: 9132136
# Property_ID: 9107396
# Property_ID: 9120890
# Property_ID: 9177461
# Property_ID: 9056570
# Property_ID: 9024318
# Property_ID: 9169037
# Property_ID: 9216552
# Property_ID: 4838845
# Property_ID: 9208820
# Property_ID: 9123458
# Property_ID: 9026337
# Property_ID: 9202765
# Property_ID: 9050878
# Property_ID: 9131615
# Property_ID: 9026937
# Property_ID: 9198112
# Property_ID: 9069072
# Property_ID: 9137583
# Property_ID: 9181962
# Property_ID: 9166020
# Property_ID: 9171951
# Property_ID: 9065520
# Property_ID: 9170932
# Property_ID: 9191645
# Property_ID: 9014772
# Property_ID: 9185541
# Property_ID: 9062742
# Property_ID: 9181218
# ...
