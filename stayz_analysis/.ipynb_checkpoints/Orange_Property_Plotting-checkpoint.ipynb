# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# Now check individual graphs in detail
sns.lmplot( x="guests", y="revenue", data=plot_ds_2, fit_reg=False
           , hue='suburb_id'
           , aspect=1.61
          , size=8)

# %%
# Plot the interest rates and payments
np.random.seed(104)

int_rates = ['4.21','5.21','6.21']
repayments = [5000,6000,7000]


car_sales = pd.DataFrame({
 'intrates': int_rates,
 'repayments': repayments
 #'sales_last_year':np.random.randint(1e3,1e4,len(cities)),
}, index=int_rates)

ax = car_sales.plot(kind='bar')

# %%
car_sales_sorted = car_sales.sort_values('repayments',ascending=False)

ax = car_sales_sorted.plot(kind='bar',facecolor='#AA0000')

ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

ax.patch.set_facecolor('#FFFFFF')

ax.spines['bottom'].set_color('#CCCCCC')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_color('#CCCCCC')
ax.spines['left'].set_linewidth(1)

# %%
ax = car_sales_sorted.plot(
    kind='bar',
    color=['#AA0000' if row.repayments > 5000 else '#000088' for name,row in car_sales_sorted.iterrows()],
)

#percent_of_goal = ["{}%".format(int(100.*row.sales/row.goal)) for name,row in car_sales_sorted.iterrows()]

for i,child in enumerate(ax.get_children()[:car_sales_sorted.index.size]):
    
    ax.text(i,child.get_bbox().y1+200, 'test', horizontalalignment ='center')
    
    ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
    ax.patch.set_facecolor('#FFFFFF')
    ax.spines['bottom'].set_color('#CCCCCC')
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['left'].set_linewidth(1)

    
#for i, v in enumerate(y):
#    ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')
    
plt.show()
