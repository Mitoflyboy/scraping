# %%
import sysconfig
import os
import numpy as np
import pandas as pd
import json
import distutils
import scrapy
import requests
import json
import logging
import string
import re
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
# Read the data file and display
train = pd.read_json('WebData/stayz_nsw_extract_2018-02-17_22-59.json')

train.head()
# Out:
#    bathrooms  bedrooms  beds  \
# 0          2         4     8
# 1          1         2     5
# 2          2         4     6
# 3          3         7    15
# 4          2         2     2
#
#                                     description_full  guests  \
# 0  Rakali Cottage features deep water lake fronta...       8
# 1  Lola's Loft is a self contained house with lov...       5
# 2  Darryl Kerrigan proclaimed in the classic Aust...       9
# 3  Secrets of Terara is an enchanted getaway just...      18
# 4  Sydney’s ultimate harbourside lifestyle awaits...       4
#
#                                         heading  init_price        lat  \
# 0                   Rakali Cottage Lake Conjola         195 -35.267900
# 1                    Top Of The Range Jindabyne         143 -36.521973
# 2          THE PALMS At Erowal Bay Pet Friendly         170 -35.098663
# 3          Secrets of Terara -Enchanted Getaway         808 -34.884420
# 4  Sydney Darling Harbour Luxury 2 Br Apartment         405 -33.870354
#
#          lng  property_id property_type         scraped_date  \
# 0  150.48200      9119008         House  2018-02-17 22:59:18
# 1  148.69348      9110247         House  2018-02-17 22:59:18
# 2  150.65290      9094119         House  2018-02-17 22:59:18
# 3  150.63110      9181518         House  2018-02-17 22:59:18
# 4  151.19789      9162472     Apartment  2018-02-17 22:59:18
#
#                                                  url
# 0  https://www.stayz.com.au//accommodation/nsw/so...
# 1  https://www.stayz.com.au//accommodation/nsw/sn...
# 2  https://www.stayz.com.au//accommodation/nsw/so...
# 3  https://www.stayz.com.au//accommodation/nsw/so...
# 4  https://www.stayz.com.au//accommodation/nsw/sy...

# %%
#http://hamelg.blogspot.com.au/2015/11/python-for-data-analysis-part-29.html

train.describe()
# Out:
#           bathrooms      bedrooms          beds        guests     init_price  \
# count  18328.000000  18328.000000  18328.000000  18328.000000   18328.000000
# mean       1.848265      2.974411      4.323821      6.681362     303.252619
# std        1.151460      1.564827      3.162374      3.782263    2324.447356
# min        0.000000      0.000000      0.000000      1.000000       0.000000
# 25%        1.000000      2.000000      3.000000      4.000000     133.000000
# 50%        2.000000      3.000000      4.000000      6.000000     204.000000
# 75%        2.000000      4.000000      5.000000      8.000000     320.000000
# max       41.000000     41.000000    100.000000    120.000000  312197.000000
#
#                 lat           lng   property_id
# count  18328.000000  18328.000000  1.832800e+04
# mean     -33.166157    151.283910  1.741173e+06
# std        2.578310      4.671677  3.370177e+06
# min      -41.449306   -100.945830  3.000000e+01
# 25%      -34.771686    150.557215  1.310150e+05
# 50%      -33.598714    151.275680  1.925720e+05
# 75%      -32.346868    152.184393  2.247738e+05
# max       45.466415    167.949000  9.228610e+06

# %%
train_s1 = train.loc[train['guests'] <= 4]

train_s2 = train_s1.loc[train_s1['bathrooms'] <= 4 ]

train_small = train_s2.loc[train_s2['beds'] <= 6 ]


train_small.head()
# Out:
#     bathrooms  bedrooms  beds  \
# 4           2         2     2
# 15          1         1     1
# 19          1         2     2
# 20          2         2     4
# 22          2         1     1
#
#                                      description_full  guests  \
# 4   Sydney’s ultimate harbourside lifestyle awaits...       4
# 15                             BOUTIQUE 5 STAR STUDIO       2
# 19  Contemporary, interior-designed coastal retrea...       4
# 20  Our 4 cottages are set in a glorious bushland ...       4
# 22                  KINDLY NO CHILDREN OR PETS PLEASE       2
#
#                                           heading  init_price        lat  \
# 4    Sydney Darling Harbour Luxury 2 Br Apartment         405 -33.870354
# 15             Cat On The Hat Cottage ~MeOw MeOw~         110 -33.631090
# 19               Retro Beach House at Pearl Beach         305 -33.538840
# 20                   TOUCHDOWN COTTAGES JINDABYNE         128 -36.428400
# 22  Sails On The Bay-Absolute Waterfront Property         260 -35.070300
#
#           lng  property_id property_type         scraped_date  \
# 4   151.19789      9162472     Apartment  2018-02-17 22:59:18
# 15  150.28883      9148849        Studio  2018-02-17 22:59:19
# 19  151.30493      9208820         House  2018-02-17 22:59:20
# 20  148.60300      9060812       Cottage  2018-02-17 22:59:20
# 22  150.67800      9077038     Apartment  2018-02-17 22:59:20
#
#                                                   url
# 4   https://www.stayz.com.au//accommodation/nsw/sy...
# 15  https://www.stayz.com.au//accommodation/nsw/bl...
# 19  https://www.stayz.com.au//accommodation/nsw/ce...
# 20  https://www.stayz.com.au//accommodation/nsw/sn...
# 22  https://www.stayz.com.au//accommodation/nsw/so...

# %%
# Testing - look in detail at any outliers

t1 = train_small.loc[train_small['init_price'] == 3300]
t1.head()
# Out:
# Empty DataFrame
# Columns: [bathrooms, bedrooms, beds, description_full, guests, heading, init_price, lat, lng, property_id, property_type, scraped_date, url]
# Index: []

# %%
train_small.describe()
# Out:
#          bathrooms     bedrooms         beds       guests   init_price  \
# count  4819.000000  4819.000000  4819.000000  4819.000000  4819.000000
# mean      1.191741     1.603860     2.106246     3.348828   180.320398
# std       0.420231     0.561082     0.919283     0.901387   111.658293
# min       0.000000     0.000000     0.000000     1.000000     0.000000
# 25%       1.000000     1.000000     1.000000     2.000000   116.500000
# 50%       1.000000     2.000000     2.000000     4.000000   165.000000
# 75%       1.000000     2.000000     3.000000     4.000000   224.000000
# max       4.000000     6.000000     6.000000     4.000000  2200.000000
#
#                lat          lng   property_id
# count  4819.000000  4819.000000  4.819000e+03
# mean    -32.972912   151.069342  2.096677e+06
# std       3.272563     8.021186  3.621929e+06
# min     -37.149223   -84.997270  7.470000e+02
# 25%     -34.180645   150.656720  1.406090e+05
# 50%     -33.711790   151.251950  1.983600e+05
# 75%     -32.179199   152.500900  2.277400e+05
# max      45.466415   153.635880  9.228590e+06

# %%
train_small['guests'].value_counts().plot(kind='bar')
plt.title('Number of Guests')
plt.xlabel('Guests')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %%
train_small['guests'].groupby(train_small['guests']).count()
# Out:
# guests
# 1       9
# 2    1383
# 3     345
# 4    3082
# Name: guests, dtype: int64

# %%
train_display = pd.DataFrame({
    'Nbr Reviews': train_small['reviews'],
    'Price': train_small['init_price'],
    'Type': train_small['property_type'],
    'Bathrooms' : train_small['bathrooms'],
    'Beds' : train_small['beds']
})


train_display.groupby('Type').hist()
# Out:
# Type
# Apartment    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# B&B          [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Cabin        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Campervan    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Chalet       [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Cottage      [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Farmstay     [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Guest        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Hotel        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# House        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Lodge        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Motel        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Other        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Resort       [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Studio       [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Townhouse    [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Villa        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# Yacht        [[AxesSubplot(0.125,0.551739;0.336957x0.328261...
# dtype: object

# %%
df = pd.DataFrame({
    'Guests': train_small['guests'],
    'Bathrooms': train_small['bathrooms'],
    'Type': train_small['property_type']
})

fg = sns.FacetGrid(data=df, hue='Type', aspect=1.61, size=8)
fg.map(plt.scatter, 'Guests', 'Bathrooms').add_legend()

# %%
df = pd.DataFrame({
    'Guests': train_small['guests'],
    'Price': train_small['init_price'],
    'Type': train_small['property_type']
})

fg = sns.FacetGrid(data=df, hue='Type', aspect=1.61, size=8)
fg.map(plt.scatter, 'Guests', 'Price').add_legend()

# %%
df = pd.DataFrame({
    'Nbr Reviews': train_small['reviews'],
    'Price': train_small['init_price'],
    'Type': train_small['property_type'],    
})

fg = sns.FacetGrid( data=df, hue='Type', aspect=1.61, size=10)
fg.map(plt.scatter, 'Nbr Reviews', 'Price').add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f58caf4ffeee> in <module>()
#       6
#       7 fg = sns.FacetGrid( data=df, hue='Type', aspect=1.61, size=10)
# ----> 8 fg.map(plt.scatter, 'Nbr Reviews', 'Price').add_legend()
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     718
#     719             # Get the actual data we are going to plot with
# --> 720             plot_data = data_ijk[list(args)]
#     721             if self._dropna:
#     722                 plot_data = plot_data.dropna()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Nbr Reviews'] not in index"

# %%
#X = train.drop(['init_price'],axis=1)
#X = X.drop(['lat'],axis=1)
#X = X.drop([''],axis=1)

X = pd.DataFrame({
    'Nbr Reviews': train_small['reviews'],
    'Price': train_small['init_price'],
    #'Type': train['property_type'],
    'Bathrooms' : train_small['bathrooms'],
    'Beds' : train_small['beds'],
    'Guests' : train_small['guests'],
    'Lat' : train_small['lat'],
    'Lon' : train_small['lng']
})
Y = train_small['init_price']

# %%
X.describe()

# %%
X.info()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(X, alpha=0.2, figsize=(12, 12), diagonal='kde')

# %%
model = DecisionTreeClassifier()
model.fit(X,Y)

# %%
print(cross_val_score(model,X,Y,cv=10,scoring='accuracy').mean())
