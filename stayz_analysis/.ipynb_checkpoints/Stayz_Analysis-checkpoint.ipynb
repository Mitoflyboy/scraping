# %% [markdown]
# # TO DO List
# 1. Get the 'Average customer ratings' for comfort, cleanliness, location, quality
# 1. Do a scatter plot of distance from sydney vs bookings count???
# 1. Distance vs revenue?
# 1. Distance vs revenue per person (assuming full occupancy)
# 1. Percentage occupancy for the month vs distance
# 1. 30/60/90 day occupancy vs distance (forward bookings)
# 1. Last 30/60/90 day actual occupance vs distance (history bookings)
# 1. Count how many places have zero bookings

# %%
import sysconfig
import os
import numpy as np
import pandas as pd
import json
import distutils
import datetime
import scrapy
import requests
import json
import logging
import string
import re
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
date_str = datetime.datetime.now().strftime("%Y-%m-%d")

print("Date: " + date_str)
# Out:
# Date: 2018-05-02

# %% [markdown]
# Dataset 1 - Load the nsw_extract daily file. This starts with the https://www.stayz.com.au/accommodation/nsw page and then follows the link to each propert. This is the quick (30 minutes) extract of raw details, as it excludes the calendar details.

# %%
# Read the data file and display
nsw_extract_1 = pd.read_json('/Users/taj/GitHub/scraping/stayz/WebData/nsw_extract/stayz_nsw_extract_' + date_str + '.json.zip')

# Reindex for 'property_id'
nsw_extract_2 = nsw_extract_1.set_index('property_id')

nsw_extract_3 = nsw_extract_2.sort_index()

nsw_extract = nsw_extract_3


print("nsw_extract index: " + str(nsw_extract.index.dtype_str))

nsw_extract.head()
# Out:
# nsw_extract index: int64
#              bathrooms  bedrooms  beds  \
# property_id
# 806                  3         3     5
# 1873                 3         6     8
# 1971                 3         6    11
# 2042                 4         5    11
# 2107                 1         2     6
#
#                                               description_full  \
# property_id
# 806          [<p><center>, </p>,  ELEGANTLY 5 STAR As seen ...
# 1873         [Large home with 6 bedrooms 1 with ensuite, 2 ...
# 1971         [Ski Cove House is a two storey waterfront on ...
# 2042         [Lavender Manor is a very spacious, gorgeously...
# 2107         [We have 6 fully self contained cottages at Je...
#
#              description_wc  guests  \
# property_id
# 806                     346       8
# 1873                    135      13
# 1971                    480      15
# 2042                    296      15
# 2107                    138       2
#
#                                                        heading  init_price  \
# property_id
# 806          'T A M B A C' Your Ultimate Beach House Experi...         408
# 1873                          Mana magic - 182 Elizabeth Drive         561
# 1971                       Ski Cove House with perfect sunsets         357
# 2042                                Lavender Manor, Blackheath         918
# 2107                 Jenolan Cabins - located at Jenolan Caves         148
#
#                   lat        lng property_type  reviews         scraped_date  \
# property_id
# 806         -32.33650  152.54400         House        6  2018-05-02 01:18:47
# 1873        -35.06640  150.67400       Cottage       29  2018-05-02 01:09:15
# 1971        -32.38740  152.50100         House       56  2018-05-02 01:19:34
# 2042        -33.64980  150.29800       Cottage        6  2018-05-02 01:16:16
# 2107        -33.83041  149.99347       Cottage        8  2018-05-02 01:07:30
#
#             syd_brg  syd_brg_deg  syd_dist_km  \
# property_id
# 806              NE           35          223
# 1873              S          201          128
# 1971             NE           34          216
# 2042             NW          294           89
# 2107              W          278          110
#
#                                                            url
# property_id
# 806          https://www.stayz.com.au//accommodation/nsw/no...
# 1873         https://www.stayz.com.au//accommodation/nsw/so...
# 1971         https://www.stayz.com.au//accommodation/nsw/no...
# 2042         https://www.stayz.com.au//accommodation/nsw/bl...
# 2107         https://www.stayz.com.au//accommodation/nsw/bl...

# %% [markdown]
# Dataset 2 - Load the full geocoded address file. This is the Google reverse geocoder API output for each of the latitude/longitude details for each property. Note that the street number is not exact for the property but is within a few houses and is the same street. Stayz deliberatly obfuscates the exact location however all other details are correct apart from house number.

# %%
# Read the data file and display
geodata_1 = pd.read_json('/Users/taj/GitHub/scraping/stayz/WebData/nsw_geocoded/stayz_geocoded_full.json')

geodata_2 = geodata_1.set_index('property_id')
geodata_3 = geodata_2.sort_index()

geodata = geodata_3


print("geodata index: " + str(geodata.index.dtype_str))

geodata.head(10)
# Out:
# geodata index: int64
#                     council  \
# property_id
# 52                  Gosford
# 717               Pittwater
# 806             Great Lakes
# 1036                Gosford
# 1266             Shoalhaven
# 1873             Shoalhaven
# 1971            Great Lakes
# 1971            Great Lakes
# 2040             Shoalhaven
# 2042         Blue Mountains
#
#                                              formatted_address postcode  \
# property_id
# 52                24 Avoca Dr, Avoca Beach NSW 2251, Australia     2251
# 717          342 Whale Beach Rd, Palm Beach NSW 2108, Austr...     2108
# 806           5 Coast Ave, Boomerang Beach NSW 2428, Australia     2428
# 1036             15 Ficus Ave, Avoca Beach NSW 2251, Australia     2251
# 1266            42 Elizabeth Dr, Vincentia NSW 2540, Australia     2540
# 1873           182 Elizabeth Dr, Vincentia NSW 2540, Australia     2540
# 1971           30 Ski Cove St, Smiths Lake NSW 2428, Australia     2428
# 1971           30 Ski Cove St, Smiths Lake NSW 2428, Australia     2428
# 2040         6 Bellbird Cl, Mollymook Beach NSW 2539, Austr...     2539
# 2042         119 Evans Lookout Rd, Blackheath NSW 2785, Aus...     2785
#
#                       st_name st_nbr state           suburb
# property_id
# 52                   Avoca Dr     24   NSW      Avoca Beach
# 717            Whale Beach Rd    342   NSW       Palm Beach
# 806                 Coast Ave      5   NSW  Boomerang Beach
# 1036                Ficus Ave     15   NSW      Avoca Beach
# 1266             Elizabeth Dr     42   NSW        Vincentia
# 1873             Elizabeth Dr    182   NSW        Vincentia
# 1971              Ski Cove St     30   NSW      Smiths Lake
# 1971              Ski Cove St     30   NSW      Smiths Lake
# 2040              Bellbird Cl      6   NSW  Mollymook Beach
# 2042         Evans Lookout Rd    119   NSW       Blackheath

# %% [markdown]
# Dataset 3 - Bookings data. This is extracted from the raw data in the nsw_calendar extracts, and each booking details are calculated including arrival date, and number of nights booked. We can aggregate this for each property.

# %%
# Read the bookings file
bk_date_str = date_str

book_1 = pd.read_json('/Users/taj/GitHub/scraping/stayz/WebData/nsw_bookings/stayz_bookings_' + bk_date_str + '.json',convert_dates=['arr_dt','dep_dt'])

# Change the index to property id
book_2 = book_1.set_index('property_id')

# Sort the dataset so that all property id bookings are together
book_3 = book_2.sort_index()


# If the booking is greater than 7 days then may not be a customer
# If the booking is greater than 14 days then assume it is blocked out and not a booking
book_3['book_type'] = book_3['book_days'].map(lambda x: 'Host' if x > 14 else 'Cust')

book_cust = book_3[book_3['book_type'] == 'Cust']

# Calculate the number of booked days for the 'Cust' type of bookings since b3 is the customers exc hosts
book_sum = book_cust.groupby(['property_id']).sum()

# Rename the column as total_booked_days
book_sum.columns = ['total_booked_days']


print("book_sum index: " + str(book_sum.index.dtype_str))

book_sum.info()
# Out:
# book_sum index: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1437 entries, 8131 to 9228448
# Data columns (total 1 columns):
# total_booked_days    1437 non-null int64
# dtypes: int64(1)
# memory usage: 22.5 KB

# %%
# Check a specific property_id to make sure the individual bookings are calculated correctly
a = book_cust.loc[8131]
a.sort_values(by=['arr_dt'])
# Out:
#                 arr_dt  book_days     dep_dt              ext_at book_type
# property_id
# 8131        2018-05-04          3 2018-05-06 2018-05-02 11:08:07      Cust
# 8131        2018-05-24          7 2018-05-30 2018-05-02 11:08:07      Cust
# 8131        2018-07-03          7 2018-07-09 2018-05-02 11:08:07      Cust

# %% [markdown]
# Dataset 4 - Calendar details

# %%
# Read the Calendar extract to get additional details
cal_1 = pd.read_json('/Users/taj/GitHub/scraping/stayz/WebData/nsw_calendar/stayz_calendar_' + date_str + '.json.zip')

# Change values of -1.0 into NaN for stats analysis
cal_1.loc[cal_1['review_count'] == -1.0, 'review_count'] = np.nan
cal_1.loc[cal_1['review_value'] == -1.0, 'review_value'] = np.nan

cal_2 = cal_1.drop(['calendar'], axis=1)

cal_3 = cal_2[(cal_2['property_id'] != 0) & (cal_2['property_id'] != '')]

cal_4 = cal_3

cal_4['property_id'] = cal_4['property_id'].astype(np.int64)

cal_5 = cal_4.set_index(['property_id'])

cal_6 = cal_5.sort_index()

cal = cal_6

cal.head()
# Out:
# /Users/taj/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          ext_at  \
# property_id
# 806         2018-05-02 17:02:07
# 1873        2018-05-02 11:50:13
# 2042        2018-05-02 15:43:11
# 2107        2018-05-02 11:04:42
# 2564        2018-05-02 12:03:19
#
#                                                       features  photos  \
# property_id
# 806          Air conditioning\nClothes dryer\nCot\nDishwash...      24
# 1873         Air conditioning\nChild's high chair\nClothes ...      22
# 2042         Books\nCeiling fan\nChild's high chair\nChildr...       8
# 2107         Clothes dryer\nCot\nDVD player\nIron and board...      11
# 2564         Clothes dryer\nDishwasher\nDVD player\nGames\n...      23
#
#              review_count  review_value
# property_id
# 806                   6.0           4.8
# 1873                 29.0           4.4
# 2042                  6.0           5.0
# 2107                  8.0           4.1
# 2564                 27.0           5.0

# %% [markdown]
# Dataset 5 - Features matrix

# %%
# Load the features CSV
feat_1 = pd.read_csv('/Users/taj/GitHub/scraping/stayz/WebData/nsw_features/stayz_nsw_features_' + date_str + '.csv')

feat_2 = feat_1.set_index('Unnamed: 0')

feat_2.index.names = ['property_id']

feat = feat_2

feat.head()
# Out:
#              f_books  f_child_s_high_chair  f_children_welcome  \
# property_id
# 9082944.0          1                     1                   1
# 9111394.0          1                     0                   0
# 9169760.0          1                     0                   0
# 9050878.0          0                     0                   0
# 9013800.0          0                     1                   0
#
#              f_clothes_dryer  f_coffee_maker  f_deck_patio  f_dining  \
# property_id
# 9082944.0                  1               1             1         1
# 9111394.0                  0               1             1         1
# 9169760.0                  0               1             1         1
# 9050878.0                  0               0             0         0
# 9013800.0                  1               1             1         1
#
#              f_dishes_and_utensils  f_dishwasher  f_dvd_player  \
# property_id
# 9082944.0                        1             1             1
# 9111394.0                        1             1             1
# 9169760.0                        1             1             1
# 9050878.0                        0             0             0
# 9013800.0                        1             1             1
#
#                         ...              f_events_allowed  \
# property_id             ...
# 9082944.0               ...                             0
# 9111394.0               ...                             0
# 9169760.0               ...                             0
# 9050878.0               ...                             0
# 9013800.0               ...                             0
#
#              f_fitness_room_equipment  f_indoor_pool  f_sauna  f_ceiling_fan  \
# property_id
# 9082944.0                           0              0        0              0
# 9111394.0                           0              0        0              0
# 9169760.0                           0              0        0              0
# 9050878.0                           0              0        0              0
# 9013800.0                           0              0        0              0
#
#              f_cot  f_eco_friendly  f_pantry_items  f_free_wifi  \
# property_id
# 9082944.0        0               0               0            0
# 9111394.0        0               0               0            0
# 9169760.0        0               0               0            0
# 9050878.0        0               0               0            0
# 9013800.0        0               0               0            0
#
#              f_free_fixed_line_internet
# property_id
# 9082944.0                             0
# 9111394.0                             0
# 9169760.0                             0
# 9050878.0                             0
# 9013800.0                             0
#
# [5 rows x 60 columns]

# %%
# Create a derived table to map the property_type to an integer
prop_type_table_1 = pd.DataFrame(nsw_extract['property_type'].unique())
prop_type_table_1.columns = ['property_type']

# Reset the index so we can filter on 'property_type'
#prop_type_table_1.reset_index(inplace=True)


# Remove the following property types:
# - Campervan
# - Caravan
# - Hotel
# - Motel
# - Other
# - Resort
# - Yacht

prop_type_table_2 = prop_type_table_1[~prop_type_table_1['property_type'].isin(['Campervan','Caravan','Hotel','Motel'
                                                                             ,'Other','Resort','Yacht'])]

# Add a column with the property type id as a generated number
prop_type_table_2['prop_type_id'] = range(len(prop_type_table_2))

#prop_type_table_2.drop(['prop_type_count'])

prop_type_table = prop_type_table_2

prop_type_table.head(25)
# Out:
# /Users/taj/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    property_type  prop_type_id
# 0          House             0
# 1        Cottage             1
# 3          Guest             2
# 4       Farmstay             3
# 5      Apartment             4
# 7      Townhouse             5
# 8            B&B             6
# 9          Villa             7
# 10         Cabin             8
# 11         Lodge             9
# 12        Studio            10
# 13        Chalet            11

# %%
# Extract the council, postcode, and suburb unique values and convert to integer:

# Join back to 'geodata' and keep the property_id!!!

council_1 = pd.DataFrame(geodata['council'].unique())
council_1.columns = ['council']
council_1['council_id'] = range(len(council_1))

council_1.head()
# Out:
#           council  council_id
# 0         Gosford           0
# 1       Pittwater           1
# 2     Great Lakes           2
# 3      Shoalhaven           3
# 4  Blue Mountains           4

# %%
# Extract the council, postcode, and suburb unique values and convert to integer:

suburb_1 = pd.DataFrame(geodata['suburb'].unique())
suburb_1.columns = ['suburb']
suburb_1['suburb_id'] = range(len(suburb_1))

suburb_1.head()
# Out:
#             suburb  suburb_id
# 0      Avoca Beach          0
# 1       Palm Beach          1
# 2  Boomerang Beach          2
# 3        Vincentia          3
# 4      Smiths Lake          4

# %%
#geodata_1 = geodata.merge()

# Join with property type, keeping property id as the index type
geodata_1 = (geodata.reset_index()
             .merge(council_1, how='left', on=['council'])
             .set_index('property_id')
            )

geodata_2 = (geodata_1.reset_index()
             .merge(suburb_1, how='left', on=['suburb'])
             .set_index('property_id')
            )

geodata_3 = geodata_2[['postcode','council_id','suburb_id']]



geodata_rev = geodata_3

geodata_rev.tail()
# Out:
#             postcode  council_id  suburb_id
# property_id
# 9228588         2251           0          0
# 9228590         2577           9         58
# 9228599         2488          12        244
# 9228610         2448          39        124
# 9228676         2481           8        108

# %%
# Update the main dataframe so that property type uses the int value instead of the text value

# %%
# Filter for 4 or less guests
nsw_data_s1 = nsw_extract.loc[nsw_extract['guests'] <= 6]

# Filter for 4 or less bathrooms
nsw_data_s2 = nsw_data_s1.loc[nsw_data_s1['bathrooms'] <= 4 ]

# Filter for 2 or less bedrooms
nsw_data_s3 = nsw_data_s2.loc[nsw_data_s2['bedrooms'] <= 2 ]

# Filter where straight line distance to Sydney between 80-150km
nsw_data_s4 = nsw_data_s3.loc[(nsw_data_s3['syd_dist_km'] >= 100) & (nsw_data_s3['syd_dist_km'] <= 250)]

# Only look at North properties
nsw_data_s5 = nsw_data_s4.loc[(nsw_data_s4['syd_brg'] == 'SW')]


# Use this to switch between the full dataset or a specific subset
#nsw_data = nsw_data_s5


# Filter out the outliers or ridiculous values
nsw_data_a1 = nsw_extract.loc[nsw_extract['init_price'] <= 10000 ]
nsw_data_a2 = nsw_data_a1.loc[nsw_data_a1['guests'] <= 8 ]
nsw_data_a3 = nsw_data_a2.loc[nsw_data_a2['syd_dist_km'] <= 1000 ]
nsw_data_a4 = nsw_data_a3.loc[nsw_data_a3['init_price'] > 0 ]


# Use this to get the subset as filtered above
#nsw_data = nsw_data_s5

# Use this to write out the full dataset
nsw_data = nsw_data_a4

nsw_data.describe()
# Out:
#           bathrooms      bedrooms          beds  description_wc        guests  \
# count  14584.000000  14584.000000  14584.000000    14584.000000  14584.000000
# mean       1.632268      2.559860      3.516045      184.488412      5.523999
# std        0.933827      1.089487      1.804971      104.148272      1.842112
# min        0.000000      0.000000      0.000000        0.000000      1.000000
# 25%        1.000000      2.000000      2.000000      109.000000      4.000000
# 50%        2.000000      3.000000      3.000000      160.000000      6.000000
# 75%        2.000000      3.000000      4.000000      232.000000      7.000000
# max       41.000000     41.000000    100.000000      784.000000      8.000000
#
#          init_price           lat           lng       reviews   syd_brg_deg  \
# count  14584.000000  14584.000000  14584.000000  14584.000000  14584.000000
# mean     250.404690    -33.095255    151.413600      5.383434    105.628497
# std      240.670213      2.253232      1.454912     11.856915    106.107130
# min        1.000000    -41.453060    141.443710      0.000000      0.000000
# 25%      132.000000    -34.737840    150.595610      0.000000     22.000000
# 50%      191.500000    -33.544083    151.283880      1.000000     32.000000
# 75%      285.000000    -32.179855    152.513802      5.000000    202.000000
# max     6050.000000    -27.438309    153.636810    195.000000    359.000000
#
#         syd_dist_km
# count  14584.000000
# mean     228.350315
# std      197.951822
# min        0.000000
# 25%       78.000000
# 50%      165.000000
# 75%      353.000000
# max      935.000000

# %%
# Testing - look in detail at any outliers

t1 = nsw_data.loc[nsw_data['init_price'] >= 600]
t1.head()
# Out:
#              bathrooms  bedrooms  beds  \
# property_id
# 2564                 3         4     5
# 12134                3         4     4
# 14482                3         4     6
# 16165                3         4     6
# 16184                1         4     5
#
#                                               description_full  \
# property_id
# 2564         [PLEASE NOTE CHANGES TO ALL NEW BOOKINGS - 7 S...
# 12134        [14 DAY MINIMUM RENTALS ONLY , Large house com...
# 14482        [Overlooking Pittwater and Ku-Ring-Gai Nationa...
# 16165        [What a position to spend a beach holiday. Les...
# 16184        [Please note we do not accept weddings., Narra...
#
#              description_wc  guests                          heading  \
# property_id
# 2564                    352       8            Long Reef Beach House
# 12134                   120       7      Tropical Retreat @ Clontarf
# 14482                   171       8             Sunsets - Clareville
# 16165                   131       8  La Maison de Plage - PALM BEACH
# 16184                   129       8             The Sea Temple......
#
#              init_price        lat        lng property_type  reviews  \
# property_id
# 2564                694 -35.013200  150.82500         House       27
# 12134               680 -33.811020  151.26172         House        1
# 14482              1020 -33.628930  151.31621         House        6
# 16165              1530 -33.598972  151.32312         House        0
# 16184               944 -33.716015  151.29951         House        1
#
#                     scraped_date syd_brg  syd_brg_deg  syd_dist_km  \
# property_id
# 2564         2018-05-02 01:09:44       S          195          118
# 12134        2018-05-02 01:11:00       N           20           21
# 14482        2018-05-02 01:09:44       N           17           42
# 16165        2018-05-02 01:10:59       N           16           45
# 16184        2018-05-02 01:18:06       N           19           32
#
#                                                            url
# property_id
# 2564         https://www.stayz.com.au//accommodation/nsw/so...
# 12134        https://www.stayz.com.au//accommodation/nsw/sy...
# 14482        https://www.stayz.com.au//accommodation/nsw/sy...
# 16165        https://www.stayz.com.au//accommodation/nsw/sy...
# 16184        https://www.stayz.com.au//accommodation/nsw/sy...

# %%
# Set the number of bars for the graph
bin_values = np.arange(start=0, stop=660, step=10)

# Create the figure
f1 = plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
ax = f1.add_subplot(221)
ax.set(title='Number of Properties vs Price'
      ,xlabel='Price ($AUD)'
      ,ylabel='Number of Properties')


# Get the initial price
x = nsw_data['init_price']

# Remove the rows where price is empty (NaN)
x = x.dropna()

print("Total number of properties: " + str(len(x)))

# Plot a histogram of the init_price
ax.hist(x, bins=bin_values, alpha=.6) # alpha for transparency

plt.show()
# Out:
# Total number of properties: 14584

# %%
nsw_data['guests'].value_counts().plot(kind='bar')
plt.title('Number of Guests')
plt.xlabel('Guests')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %%
nsw_data['guests'].groupby(nsw_data['guests']).count()
# Out:
# guests
# 1       8
# 2    1403
# 3     339
# 4    3073
# 5    1381
# 6    4208
# 7    1090
# 8    3082
# Name: guests, dtype: int64

# %% [markdown]
# Combined Data set - merge the 4 data files together to get the complete picture.
# * nsw_data
# * geodata
# * cal
# * book_sum

# %%
# Merge the nsw_extract with the geocoded data: only need the postcode, council, suburb. 
# Convert them to integer values first


full_dataset_1 = nsw_data.merge(geodata_rev, how='left', left_index=True, right_index=True)

full_dataset_2 = full_dataset_1.merge(cal, how='left', left_index=True, right_index=True)

full_dataset_3 = full_dataset_2.merge(book_sum, how='left', left_index=True, right_index=True)

full_dataset_4 = full_dataset_3.merge(feat, how='left', left_index=True, right_index=True)

# Join with property type, keeping property id as the index type
full_dataset_5 = (full_dataset_4.reset_index()
                  .merge(prop_type_table, how='inner', on=['property_type'])
                  .set_index('property_id')
                 )

full_dataset_3.head()
# Out:
#              bathrooms  bedrooms  beds  \
# property_id
# 806                  3         3     5
# 2107                 1         2     6
# 2107                 1         2     6
# 2564                 3         4     5
# 3333                 1         1     3
#
#                                               description_full  \
# property_id
# 806          [<p><center>, </p>,  ELEGANTLY 5 STAR As seen ...
# 2107         [We have 6 fully self contained cottages at Je...
# 2107         [We have 6 fully self contained cottages at Je...
# 2564         [PLEASE NOTE CHANGES TO ALL NEW BOOKINGS - 7 S...
# 3333         [Lakeview Plaza Motel standard rooms are great...
#
#              description_wc  guests  \
# property_id
# 806                     346       8
# 2107                    138       2
# 2107                    138       2
# 2564                    352       8
# 3333                    194       4
#
#                                                        heading  init_price  \
# property_id
# 806          'T A M B A C' Your Ultimate Beach House Experi...         408
# 2107                 Jenolan Cabins - located at Jenolan Caves         148
# 2107                 Jenolan Cabins - located at Jenolan Caves         148
# 2564                                     Long Reef Beach House         694
# 3333                             Lakeview Plaza Motel standard         250
#
#                   lat        lng        ...          \
# property_id                             ...
# 806         -32.33650  152.54400        ...
# 2107        -33.83041  149.99347        ...
# 2107        -33.83041  149.99347        ...
# 2564        -35.01320  150.82500        ...
# 3333        -36.41580  148.62100        ...
#
#                                                            url  postcode  \
# property_id
# 806          https://www.stayz.com.au//accommodation/nsw/no...      2428
# 2107         https://www.stayz.com.au//accommodation/nsw/bl...      2790
# 2107         https://www.stayz.com.au//accommodation/nsw/bl...      2790
# 2564         https://www.stayz.com.au//accommodation/nsw/so...      2540
# 3333         https://www.stayz.com.au//accommodation/nsw/sn...      2627
#
#             council_id suburb_id              ext_at  \
# property_id
# 806                2.0       2.0 2018-05-02 17:02:07
# 2107               5.0       7.0 2018-05-02 11:04:42
# 2107               5.0       7.0 2018-05-02 11:04:42
# 2564               3.0       8.0 2018-05-02 12:03:19
# 3333               6.0       9.0 2018-05-02 11:17:04
#
#                                                       features photos  \
# property_id
# 806          Air conditioning\nClothes dryer\nCot\nDishwash...   24.0
# 2107         Clothes dryer\nCot\nDVD player\nIron and board...   11.0
# 2107         Clothes dryer\nCot\nDVD player\nIron and board...   11.0
# 2564         Clothes dryer\nDishwasher\nDVD player\nGames\n...   23.0
# 3333         Children welcome\nHair dryer\nHeating\nIron an...   10.0
#
#             review_count  review_value  total_booked_days
# property_id
# 806                  6.0           4.8                NaN
# 2107                 8.0           4.1                NaN
# 2107                 8.0           4.1                NaN
# 2564                27.0           5.0                NaN
# 3333                 5.0           NaN                NaN
#
# [5 rows x 26 columns]

# %%
# Drop some unnecessary columns
full_dataset_5.drop(columns=['lat', 'lng','syd_brg','scraped_date','property_type','features','url','description_full','heading'],inplace=True)

# Replace any 'NaN' values with zeros
full_dataset_5.fillna(0,inplace=True)

# Sort based on the total booked days for the current 6 month window, sort descending
#full_dataset_6 = full_dataset_5.sort_values(by=['property_id'], ascending=False)

full_dataset = full_dataset_5


# Write out the full dataset

full_dataset.head()

# Can we use a random forest, with the 'total_booked_days' as the result column?
# Out:
#              bathrooms  bedrooms  beds  description_wc  guests  init_price  \
# property_id
# 806                  3         3     5             346       8         408
# 2564                 3         4     5             352       8         694
# 4121                 2         2     3             411       6         165
# 4313                 2         3     4              76       6         126
# 5144                 2         2     2             220       4         193
#
#              reviews  syd_brg_deg  syd_dist_km postcode      ...       \
# property_id                                                  ...
# 806                6           35          223     2428      ...
# 2564              27          195          118     2540      ...
# 4121              23          200          110     2540      ...
# 4313               0           31          248     2430      ...
# 5144              18          214          104     2577      ...
#
#              f_fitness_room_equipment  f_indoor_pool f_sauna  f_ceiling_fan  \
# property_id
# 806                               0.0            0.0     0.0            0.0
# 2564                              0.0            0.0     0.0            0.0
# 4121                              0.0            0.0     0.0            0.0
# 4313                              0.0            0.0     0.0            0.0
# 5144                              0.0            0.0     0.0            0.0
#
#              f_cot  f_eco_friendly  f_pantry_items  f_free_wifi  \
# property_id
# 806            1.0             1.0             0.0          0.0
# 2564           0.0             0.0             0.0          0.0
# 4121           0.0             0.0             0.0          0.0
# 4313           0.0             0.0             0.0          0.0
# 5144           0.0             0.0             0.0          0.0
#
#              f_free_fixed_line_internet  prop_type_id
# property_id
# 806                                 0.0             0
# 2564                                0.0             0
# 4121                                0.0             0
# 4313                                0.0             0
# 5144                                0.0             0
#
# [5 rows x 78 columns]

# %%
# Write out the full dataset

csv_out = full_dataset.to_csv()

fh = open('/Users/taj/GitHub/scraping/stayz/WebData/nsw_fulldata/stayz_nsw_fulldata_' + date_str + '.csv', 'w')

fh.write(csv_out)

fh.close()

# %%
# Histogram of how many properties get bookings

# Set the number of bars for the graph
bin_values = np.arange(start=0, stop=120, step=5)

# Create the figure
f1 = plt.figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
ax = f1.add_subplot(221)
ax.set(title='Number of Properties vs Days Booked'
      ,xlabel='Days Booked'
      ,ylabel='Number of Properties')


# Get the initial price
x = plot_ds['total_booked_days']

#x = full_dataset['total_booked_days']


# Remove the rows where price is empty (NaN)
x = x.dropna()

print("Total number of properties: " + str(len(x)))

# Plot a histogram of the init_price
ax.hist(x, bins=bin_values, alpha=.6) # alpha for transparency

plt.show()
# Out:
# Total number of properties: 1197

# %%
# Plot the bookings vs the initial price

plot_ds = full_dataset[full_dataset['total_booked_days'] > 0]

plt.figure(figsize=(20,12))

plt.title('Number of Days Booked vs Price')
plt.xlabel('Initial Price per night ($AUD)')
plt.ylabel('Number of Days Booked')
plt.scatter(plot_ds['init_price'],plot_ds['total_booked_days'])

plt.show()

# %%
# Now draw a graph of Initial Price vs Distance from Sydney
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20,12))


#nsw_data_s6 = nsw_data_s5[nsw_data_s5['syd_dist_km'] <= 250]

#nsw_data_s7 = nsw_data_s6[nsw_data_s6['init_price'] <= 600]

plt.title('Distance from Sydney vs Price')
plt.xlabel('Initial Price per night ($AUD)')
plt.ylabel('Distance from Sydney (km)')
plt.scatter(full_dataset['init_price'],full_dataset['syd_dist_km'])

plt.show()

# %%
# Now check individual graphs in detail
sns.lmplot( x="reviews", y="total_booked_days", data=plot_ds, fit_reg=False
           , hue='prop_type_id'
           , aspect=1.61
          , size=8)

# %%
# Now check individual graphs in detail

# Try just one property_type - House

nsw_data_s8 = plot_ds[plot_ds['prop_type_id'] == 1]

sns.lmplot( x="syd_dist_km", y="total_booked_days", data=nsw_data_s8, fit_reg=False
           , hue='prop_type_id'
           , aspect=1.61
          , size=8)

# %%
test_cor = full_dataset.corr(method='pearson')

test_cor
# Out:
#                              bathrooms  bedrooms      beds  description_wc  \
# bathrooms                     1.000000  0.246651  0.143645        0.111745
# bedrooms                      0.246651  1.000000  0.652360       -0.101953
# beds                          0.143645  0.652360  1.000000       -0.058390
# description_wc                0.111745 -0.101953 -0.058390        1.000000
# guests                        0.119708  0.746208  0.744169       -0.072125
# init_price                    0.180851 -0.020539 -0.104999        0.156802
# reviews                       0.016640 -0.036786 -0.018930        0.213812
# syd_brg_deg                   0.019073 -0.229673 -0.160858        0.062501
# syd_dist_km                   0.005763  0.144292  0.118718       -0.068846
# council_id                   -0.050127 -0.123030 -0.074585       -0.042193
# suburb_id                    -0.002588 -0.222203 -0.119663        0.265724
# photos                        0.041407  0.158738  0.137842        0.189057
# review_count                  0.008720 -0.014762 -0.026370        0.168707
# review_value                 -0.024234  0.075485  0.142495       -0.006581
# total_booked_days            -0.066301 -0.061399  0.024414        0.046643
# f_balcony                     0.147443  0.047472  0.036726        0.107819
# f_books                       0.106746  0.044377  0.057013        0.239294
# f_child_s_high_chair         -0.032790  0.023680  0.161595        0.053360
# f_children_welcome            0.096882  0.086554  0.202386        0.181612
# f_clothes_dryer               0.229305  0.121620  0.107831        0.214223
# f_deck_patio                  0.059342  0.057228  0.056346        0.181980
# f_dining                      0.038560  0.112261  0.122933        0.137414
# f_dishes_and_utensils         0.084836  0.018794  0.045644        0.168241
# f_dishwasher                  0.242196  0.152038  0.156754        0.130549
# f_dvd_player                  0.071502  0.174683  0.182387        0.131536
# f_fireplace                   0.025820  0.019505  0.041784        0.066503
# f_heating                     0.058074  0.037189  0.080952        0.181380
# f_internet_access             0.078339 -0.113305 -0.122266        0.187189
# f_iron_and_board              0.107016 -0.016238  0.070726        0.201377
# f_kitchen                     0.059802  0.150628  0.185518        0.068582
# ...                                ...       ...       ...             ...
# f_coffee_maker                0.160247  0.012774  0.076286        0.201306
# f_games                       0.184363  0.133569  0.202632        0.296168
# f_hair_dryer                  0.076342 -0.056177  0.034354        0.274647
# f_linens_provided             0.056849 -0.164936 -0.085587        0.146519
# f_pets_allowed                0.079450  0.072816  0.062553        0.022052
# f_tennis                     -0.030998  0.037312  0.115776        0.045125
# f_towels_provided             0.106081 -0.135584 -0.026999        0.163938
# f_video_library               0.147379  0.039097  0.047859        0.305228
# f_wheelchair_accessible       0.066621 -0.009556  0.097012        0.047013
# f_air_conditioning            0.030992 -0.004923  0.021335        0.124341
# f_games_room                  0.024480  0.058805  0.018733        0.008840
# f_garage                      0.084731  0.139518  0.079974       -0.063424
# f_hot_tub                     0.081365 -0.037408  0.037961        0.113245
# f_long_term_renters_welcome   0.004443 -0.054772 -0.056165        0.144153
# f_video_games                 0.042773 -0.047253  0.008404        0.073904
# f_private_pool               -0.084130 -0.008476 -0.021764       -0.091173
# f_communal_pool              -0.036858 -0.038559  0.049355        0.042684
# f_events_allowed              0.055692 -0.054269 -0.002640        0.134047
# f_heated_pool                 0.125617  0.065817  0.063039       -0.007447
# f_telephone                   0.044374 -0.000084 -0.042450        0.059287
# f_sauna                      -0.019038 -0.073379  0.103009       -0.010478
# f_fitness_room_equipment           NaN       NaN       NaN             NaN
# f_indoor_pool                -0.046887 -0.012120 -0.019729        0.036666
# f_ceiling_fan                 0.011154  0.040483  0.152054       -0.041715
# f_pantry_items                0.078058  0.068570  0.064629       -0.044591
# f_cot                        -0.004507 -0.000119  0.074930       -0.055904
# f_eco_friendly                0.034771 -0.026219 -0.032718        0.002988
# f_free_wifi                        NaN       NaN       NaN             NaN
# f_free_fixed_line_internet         NaN       NaN       NaN             NaN
# prop_type_id                 -0.042782 -0.204539 -0.152384        0.105770
#
#                                guests  init_price   reviews  syd_brg_deg  \
# bathrooms                    0.119708    0.180851  0.016640     0.019073
# bedrooms                     0.746208   -0.020539 -0.036786    -0.229673
# beds                         0.744169   -0.104999 -0.018930    -0.160858
# description_wc              -0.072125    0.156802  0.213812     0.062501
# guests                       1.000000   -0.135907  0.003506    -0.239969
# init_price                  -0.135907    1.000000  0.044217     0.200614
# reviews                      0.003506    0.044217  1.000000     0.057965
# syd_brg_deg                 -0.239969    0.200614  0.057965     1.000000
# syd_dist_km                  0.133752   -0.354345 -0.084165    -0.430755
# council_id                  -0.118218   -0.170125 -0.049941     0.436939
# suburb_id                   -0.173373    0.008283 -0.001145     0.216250
# photos                       0.187238   -0.006340 -0.001538    -0.077517
# review_count                 0.017262    0.035147  0.661451     0.014832
# review_value                 0.120005    0.002264 -0.010703     0.015241
# total_booked_days           -0.027949   -0.011269  0.209437    -0.004608
# f_balcony                   -0.008940    0.193826 -0.007624     0.031942
# f_books                      0.048755    0.177114  0.187134     0.102181
# f_child_s_high_chair         0.098555   -0.007998  0.202951     0.120957
# f_children_welcome           0.151951    0.080089  0.111642     0.080298
# f_clothes_dryer              0.079727    0.137011  0.127790     0.134657
# f_deck_patio                 0.078903    0.097451  0.022905     0.020211
# f_dining                     0.166265    0.032638  0.027130    -0.023154
# f_dishes_and_utensils        0.039659    0.146444  0.093664     0.081852
# f_dishwasher                 0.178368    0.113079  0.000915     0.027535
# f_dvd_player                 0.196263   -0.025369  0.087980    -0.025273
# f_fireplace                 -0.031319    0.116080  0.034986     0.242980
# f_heating                    0.059705    0.101626  0.079003     0.134270
# f_internet_access           -0.104269    0.163040 -0.011771     0.085583
# f_iron_and_board            -0.002138    0.093086  0.184165     0.150270
# f_kitchen                    0.207948    0.048327  0.019048    -0.035317
# ...                               ...         ...       ...          ...
# f_coffee_maker               0.046731    0.100323  0.072257     0.127454
# f_games                      0.150269    0.165470  0.103763     0.068303
# f_hair_dryer                -0.031800    0.146695  0.143086     0.164251
# f_linens_provided           -0.193863    0.224468  0.053789     0.230839
# f_pets_allowed               0.062683    0.033958  0.147988    -0.001422
# f_tennis                     0.143536   -0.091942  0.032427     0.081646
# f_towels_provided           -0.153741    0.145395  0.093188     0.253017
# f_video_library             -0.010417    0.126844  0.190385     0.142684
# f_wheelchair_accessible     -0.013688    0.165162  0.045324     0.061537
# f_air_conditioning           0.043956    0.117122  0.047001    -0.043525
# f_games_room                 0.117610   -0.068904 -0.037625    -0.053754
# f_garage                     0.157734   -0.044590 -0.046175    -0.053623
# f_hot_tub                   -0.002411    0.156926  0.075301     0.082450
# f_long_term_renters_welcome -0.017900    0.008391  0.036233     0.151587
# f_video_games               -0.009767   -0.008154  0.055063     0.090456
# f_private_pool               0.017319   -0.012703 -0.063373    -0.015544
# f_communal_pool              0.055525   -0.024810  0.031816     0.146799
# f_events_allowed            -0.035664    0.084522 -0.004039     0.036333
# f_heated_pool                0.041021    0.134798  0.002424     0.098240
# f_telephone                 -0.020766   -0.009695 -0.012749     0.060808
# f_sauna                      0.032300    0.050556  0.021332     0.007682
# f_fitness_room_equipment          NaN         NaN       NaN          NaN
# f_indoor_pool               -0.064467    0.047634  0.084864     0.047217
# f_ceiling_fan                0.116401   -0.013798 -0.045821    -0.043986
# f_pantry_items               0.026083    0.195661 -0.068232     0.048998
# f_cot                        0.065516    0.079354  0.010044     0.072282
# f_eco_friendly              -0.045437    0.074674  0.053781     0.067236
# f_free_wifi                       NaN         NaN       NaN          NaN
# f_free_fixed_line_internet        NaN         NaN       NaN          NaN
# prop_type_id                -0.140285   -0.101801 -0.039473    -0.032927
#
#                              syd_dist_km  council_id      ...        f_sauna  \
# bathrooms                       0.005763   -0.050127      ...      -0.019038
# bedrooms                        0.144292   -0.123030      ...      -0.073379
# beds                            0.118718   -0.074585      ...       0.103009
# description_wc                 -0.068846   -0.042193      ...      -0.010478
# guests                          0.133752   -0.118218      ...       0.032300
# init_price                     -0.354345   -0.170125      ...       0.050556
# reviews                        -0.084165   -0.049941      ...       0.021332
# syd_brg_deg                    -0.430755    0.436939      ...       0.007682
# syd_dist_km                     1.000000    0.361337      ...      -0.059558
# council_id                      0.361337    1.000000      ...      -0.017359
# suburb_id                       0.046770    0.389231      ...       0.068052
# photos                          0.018470   -0.002098      ...       0.052707
# review_count                   -0.046311   -0.024493      ...       0.040342
# review_value                   -0.062680   -0.055899      ...       0.065535
# total_booked_days              -0.039039   -0.013088      ...       0.085579
# f_balcony                      -0.038891    0.015053      ...      -0.020471
# f_books                        -0.067132    0.035716      ...      -0.022688
# f_child_s_high_chair           -0.008760    0.099461      ...       0.132286
# f_children_welcome             -0.052454    0.057146      ...       0.072995
# f_clothes_dryer                -0.054011    0.068443      ...       0.105884
# f_deck_patio                   -0.138508   -0.065287      ...       0.060910
# f_dining                       -0.017665    0.024658      ...       0.054669
# f_dishes_and_utensils          -0.066490    0.088795      ...       0.056141
# f_dishwasher                    0.031040    0.011584      ...      -0.028384
# f_dvd_player                   -0.084211   -0.049562      ...       0.048617
# f_fireplace                    -0.147432    0.105225      ...      -0.016077
# f_heating                      -0.113232    0.016817      ...       0.058987
# f_internet_access               0.089421    0.131830      ...       0.132286
# f_iron_and_board               -0.083472    0.104660      ...       0.064438
# f_kitchen                      -0.052561   -0.079536      ...       0.042184
# ...                                  ...         ...      ...            ...
# f_coffee_maker                 -0.060185    0.078595      ...       0.087604
# f_games                         0.008424    0.047848      ...       0.102640
# f_hair_dryer                   -0.088939    0.074464      ...       0.087604
# f_linens_provided              -0.215292    0.066911      ...       0.062342
# f_pets_allowed                 -0.051293   -0.028911      ...       0.125479
# f_tennis                       -0.049729    0.029171      ...      -0.014786
# f_towels_provided              -0.156246    0.120509      ...       0.077015
# f_video_library                -0.037147    0.080319      ...       0.101102
# f_wheelchair_accessible        -0.047397    0.030352      ...       0.203522
# f_air_conditioning             -0.103742   -0.062409      ...       0.072614
# f_games_room                    0.061411   -0.008602      ...      -0.004315
# f_garage                        0.037272   -0.023183      ...      -0.014015
# f_hot_tub                      -0.155009   -0.054950      ...       0.245935
# f_long_term_renters_welcome     0.065124    0.261873      ...      -0.013818
# f_video_games                   0.021905    0.216804      ...       0.285240
# f_private_pool                 -0.049327   -0.011200      ...       0.176789
# f_communal_pool                -0.072700    0.062972      ...      -0.010323
# f_events_allowed               -0.031055   -0.042750      ...      -0.005296
# f_heated_pool                  -0.118931   -0.030694      ...      -0.004830
# f_telephone                     0.066035    0.177261      ...      -0.005727
# f_sauna                        -0.059558   -0.017359      ...       1.000000
# f_fitness_room_equipment             NaN         NaN      ...            NaN
# f_indoor_pool                  -0.077982   -0.021289      ...      -0.005296
# f_ceiling_fan                  -0.012085   -0.010222      ...      -0.013418
# f_pantry_items                 -0.051051    0.060706      ...      -0.010074
# f_cot                          -0.079379   -0.008348      ...      -0.008161
# f_eco_friendly                 -0.051333    0.012984      ...      -0.006129
# f_free_wifi                          NaN         NaN      ...            NaN
# f_free_fixed_line_internet           NaN         NaN      ...            NaN
# prop_type_id                   -0.039148   -0.029153      ...       0.114043
#
#                              f_fitness_room_equipment  f_indoor_pool  \
# bathrooms                                         NaN      -0.046887
# bedrooms                                          NaN      -0.012120
# beds                                              NaN      -0.019729
# description_wc                                    NaN       0.036666
# guests                                            NaN      -0.064467
# init_price                                        NaN       0.047634
# reviews                                           NaN       0.084864
# syd_brg_deg                                       NaN       0.047217
# syd_dist_km                                       NaN      -0.077982
# council_id                                        NaN      -0.021289
# suburb_id                                         NaN      -0.017580
# photos                                            NaN       0.079183
# review_count                                      NaN       0.142869
# review_value                                      NaN       0.062129
# total_booked_days                                 NaN      -0.035808
# f_balcony                                         NaN       0.104150
# f_books                                           NaN      -0.007657
# f_child_s_high_chair                              NaN       0.081905
# f_children_welcome                                NaN      -0.030503
# f_clothes_dryer                                   NaN       0.001778
# f_deck_patio                                      NaN       0.031527
# f_dining                                          NaN       0.057465
# f_dishes_and_utensils                             NaN       0.021962
# f_dishwasher                                      NaN       0.015595
# f_dvd_player                                      NaN       0.119733
# f_fireplace                                       NaN      -0.039595
# f_heating                                         NaN       0.106096
# f_internet_access                                 NaN       0.020934
# f_iron_and_board                                  NaN       0.158696
# f_kitchen                                         NaN       0.065648
# ...                                               ...            ...
# f_coffee_maker                                    NaN      -0.060457
# f_games                                           NaN       0.100589
# f_hair_dryer                                      NaN      -0.014423
# f_linens_provided                                 NaN       0.074037
# f_pets_allowed                                    NaN      -0.042208
# f_tennis                                          NaN       0.226666
# f_towels_provided                                 NaN       0.103524
# f_video_library                                   NaN      -0.002156
# f_wheelchair_accessible                           NaN       0.061852
# f_air_conditioning                                NaN       0.136870
# f_games_room                                      NaN      -0.010627
# f_garage                                          NaN      -0.034516
# f_hot_tub                                         NaN       0.187536
# f_long_term_renters_welcome                       NaN      -0.034030
# f_video_games                                     NaN      -0.018568
# f_private_pool                                    NaN       0.047600
# f_communal_pool                                   NaN      -0.025422
# f_events_allowed                                  NaN      -0.013043
# f_heated_pool                                     NaN      -0.011894
# f_telephone                                       NaN      -0.014104
# f_sauna                                           NaN      -0.005296
# f_fitness_room_equipment                          NaN            NaN
# f_indoor_pool                                     NaN       1.000000
# f_ceiling_fan                                     NaN      -0.033046
# f_pantry_items                                    NaN      -0.024810
# f_cot                                             NaN       0.091406
# f_eco_friendly                                    NaN      -0.015094
# f_free_wifi                                       NaN            NaN
# f_free_fixed_line_internet                        NaN            NaN
# prop_type_id                                      NaN       0.117980
#
#                              f_ceiling_fan  f_pantry_items     f_cot  \
# bathrooms                         0.011154        0.078058 -0.004507
# bedrooms                          0.040483        0.068570 -0.000119
# beds                              0.152054        0.064629  0.074930
# description_wc                   -0.041715       -0.044591 -0.055904
# guests                            0.116401        0.026083  0.065516
# init_price                       -0.013798        0.195661  0.079354
# reviews                          -0.045821       -0.068232  0.010044
# syd_brg_deg                      -0.043986        0.048998  0.072282
# syd_dist_km                      -0.012085       -0.051051 -0.079379
# council_id                       -0.010222        0.060706 -0.008348
# suburb_id                        -0.095055        0.017483 -0.031641
# photos                            0.098007        0.059826  0.072985
# review_count                      0.010869       -0.037379  0.057646
# review_value                      0.193900        0.030277  0.085379
# total_booked_days                -0.060787       -0.042986 -0.064001
# f_balcony                         0.089822        0.212103  0.058414
# f_books                           0.062042        0.234381  0.073120
# f_child_s_high_chair             -0.024198        0.056386  0.340969
# f_children_welcome                0.118052        0.250518  0.138153
# f_clothes_dryer                   0.070121        0.214507  0.162380
# f_deck_patio                      0.213281        0.113624 -0.003582
# f_dining                          0.194466        0.193183  0.003609
# f_dishes_and_utensils             0.121119        0.262990  0.110651
# f_dishwasher                      0.201969        0.192291  0.061676
# f_dvd_player                      0.190695        0.103472  0.134167
# f_fireplace                       0.107446        0.258932  0.101458
# f_heating                         0.136456        0.191159  0.120370
# f_internet_access                -0.101433        0.122656  0.018837
# f_iron_and_board                  0.096913        0.170944  0.111976
# f_kitchen                         0.214761        0.176824  0.134836
# ...                                    ...             ...       ...
# f_coffee_maker                    0.099525        0.135181  0.089249
# f_games                           0.019214        0.149975  0.087999
# f_hair_dryer                      0.060650        0.185216  0.028445
# f_linens_provided                 0.002953        0.140826  0.052839
# f_pets_allowed                   -0.032781        0.078783  0.050939
# f_tennis                          0.157688        0.002224  0.117631
# f_towels_provided                -0.010538        0.173504  0.093153
# f_video_library                  -0.005462        0.118738  0.118311
# f_wheelchair_accessible           0.008281        0.141527  0.075968
# f_air_conditioning                0.187296        0.180525  0.026166
# f_games_room                     -0.026923       -0.020213 -0.016376
# f_garage                          0.115721        0.009058 -0.007793
# f_hot_tub                         0.166141        0.072659  0.035852
# f_long_term_renters_welcome       0.119366        0.162066  0.039429
# f_video_games                     0.003702        0.095302  0.050753
# f_private_pool                    0.120595       -0.056983  0.005056
# f_communal_pool                   0.087178        0.097968  0.138641
# f_events_allowed                  0.109540        0.066948  0.202912
# f_heated_pool                     0.125892        0.278595  0.225704
# f_telephone                      -0.035732       -0.026827 -0.021734
# f_sauna                          -0.013418       -0.010074 -0.008161
# f_fitness_room_equipment               NaN             NaN       NaN
# f_indoor_pool                    -0.033046       -0.024810  0.091406
# f_ceiling_fan                     1.000000        0.247101  0.090327
# f_pantry_items                    0.247101        1.000000  0.264762
# f_cot                             0.090327        0.264762  1.000000
# f_eco_friendly                    0.147387        0.210202  0.170295
# f_free_wifi                            NaN             NaN       NaN
# f_free_fixed_line_internet             NaN             NaN       NaN
# prop_type_id                     -0.039690       -0.013910  0.027345
#
#                              f_eco_friendly  f_free_wifi  \
# bathrooms                          0.034771          NaN
# bedrooms                          -0.026219          NaN
# beds                              -0.032718          NaN
# description_wc                     0.002988          NaN
# guests                            -0.045437          NaN
# init_price                         0.074674          NaN
# reviews                            0.053781          NaN
# syd_brg_deg                        0.067236          NaN
# syd_dist_km                       -0.051333          NaN
# council_id                         0.012984          NaN
# suburb_id                         -0.069980          NaN
# photos                             0.079916          NaN
# review_count                       0.105531          NaN
# review_value                       0.105815          NaN
# total_booked_days                 -0.047680          NaN
# f_balcony                          0.075807          NaN
# f_books                            0.102738          NaN
# f_child_s_high_chair               0.112421          NaN
# f_children_welcome                 0.135032          NaN
# f_clothes_dryer                    0.121941          NaN
# f_deck_patio                       0.105037          NaN
# f_dining                           0.055336          NaN
# f_dishes_and_utensils              0.126354          NaN
# f_dishwasher                       0.104620          NaN
# f_dvd_player                       0.105480          NaN
# f_fireplace                        0.274459          NaN
# f_heating                          0.100108          NaN
# f_internet_access                 -0.046331          NaN
# f_iron_and_board                   0.148802          NaN
# f_kitchen                          0.087033          NaN
# ...                                     ...          ...
# f_coffee_maker                     0.129807          NaN
# f_games                            0.160432          NaN
# f_hair_dryer                       0.169761          NaN
# f_linens_provided                  0.143174          NaN
# f_pets_allowed                     0.103576          NaN
# f_tennis                          -0.042138          NaN
# f_towels_provided                  0.182106          NaN
# f_video_library                    0.200948          NaN
# f_wheelchair_accessible            0.046154          NaN
# f_air_conditioning                 0.097690          NaN
# f_games_room                      -0.012298          NaN
# f_garage                           0.019715          NaN
# f_hot_tub                          0.247263          NaN
# f_long_term_renters_welcome        0.081352          NaN
# f_video_games                     -0.021487          NaN
# f_private_pool                     0.032646          NaN
# f_communal_pool                    0.048475          NaN
# f_events_allowed                   0.277984          NaN
# f_heated_pool                      0.467290          NaN
# f_telephone                       -0.016321          NaN
# f_sauna                           -0.006129          NaN
# f_fitness_room_equipment                NaN          NaN
# f_indoor_pool                     -0.015094          NaN
# f_ceiling_fan                      0.147387          NaN
# f_pantry_items                     0.210202          NaN
# f_cot                              0.170295          NaN
# f_eco_friendly                     1.000000          NaN
# f_free_wifi                             NaN          NaN
# f_free_fixed_line_internet              NaN          NaN
# prop_type_id                      -0.044711          NaN
#
#                              f_free_fixed_line_internet  prop_type_id
# bathrooms                                           NaN     -0.042782
# bedrooms                                            NaN     -0.204539
# beds                                                NaN     -0.152384
# description_wc                                      NaN      0.105770
# guests                                              NaN     -0.140285
# init_price                                          NaN     -0.101801
# reviews                                             NaN     -0.039473
# syd_brg_deg                                         NaN     -0.032927
# syd_dist_km                                         NaN     -0.039148
# council_id                                          NaN     -0.029153
# suburb_id                                           NaN     -0.031030
# photos                                              NaN     -0.035067
# review_count                                        NaN     -0.017645
# review_value                                        NaN     -0.070819
# total_booked_days                                   NaN     -0.006214
# f_balcony                                           NaN     -0.021258
# f_books                                             NaN      0.016977
# f_child_s_high_chair                                NaN      0.038633
# f_children_welcome                                  NaN      0.026935
# f_clothes_dryer                                     NaN      0.056519
# f_deck_patio                                        NaN      0.034772
# f_dining                                            NaN      0.031583
# f_dishes_and_utensils                               NaN      0.105330
# f_dishwasher                                        NaN     -0.106341
# f_dvd_player                                        NaN      0.009626
# f_fireplace                                         NaN     -0.124130
# f_heating                                           NaN      0.001504
# f_internet_access                                   NaN      0.081616
# f_iron_and_board                                    NaN      0.017972
# f_kitchen                                           NaN     -0.040599
# ...                                                 ...           ...
# f_coffee_maker                                      NaN      0.032717
# f_games                                             NaN      0.000557
# f_hair_dryer                                        NaN      0.039549
# f_linens_provided                                   NaN      0.003494
# f_pets_allowed                                      NaN     -0.111994
# f_tennis                                            NaN      0.081264
# f_towels_provided                                   NaN      0.012052
# f_video_library                                     NaN      0.026540
# f_wheelchair_accessible                             NaN     -0.033067
# f_air_conditioning                                  NaN      0.077432
# f_games_room                                        NaN     -0.016166
# f_garage                                            NaN     -0.088212
# f_hot_tub                                           NaN      0.009905
# f_long_term_renters_welcome                         NaN      0.005006
# f_video_games                                       NaN      0.034179
# f_private_pool                                      NaN     -0.045574
# f_communal_pool                                     NaN      0.171118
# f_events_allowed                                    NaN      0.067862
# f_heated_pool                                       NaN     -0.045514
# f_telephone                                         NaN     -0.102743
# f_sauna                                             NaN      0.114043
# f_fitness_room_equipment                            NaN           NaN
# f_indoor_pool                                       NaN      0.117980
# f_ceiling_fan                                       NaN     -0.039690
# f_pantry_items                                      NaN     -0.013910
# f_cot                                               NaN      0.027345
# f_eco_friendly                                      NaN     -0.044711
# f_free_wifi                                         NaN           NaN
# f_free_fixed_line_internet                          NaN           NaN
# prop_type_id                                        NaN      1.000000
#
# [76 rows x 76 columns]

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);
    
plot_corr(full_dataset)
