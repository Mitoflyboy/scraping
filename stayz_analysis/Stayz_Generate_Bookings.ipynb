# %%
import pandas as pd
import datetime

# %%
#date_str = datetime.datetime.now().strftime("%Y-%m-%d")
date_str = '2018-02-26'

js = pd.read_json('/Users/taj/GitHub/scraping/chrome_stayz_calendar/WebData/stayz_processed_calendar_' + date_str + '.json')

js.head()
# Out:
#                                             calendar property_id
# 0  {'2': {'1': 'UVL', '2': 'DEP', '3': 'AVL', '4'...     9153367
# 1  {'2': {'1': 'AVL', '2': 'AVL', '3': 'AVL', '4'...     9076897
# 2  {'2': {'1': 'AVL', '2': 'AVL', '3': 'AVL', '4'...     9123458
# 3  {'2': {'1': 'AVL', '2': 'AVL', '3': 'AVL', '4'...     9114125
# 4  {'2': {'1': 'ARR', '2': 'UVL', '3': 'UVL', '4'...     9063683

# %%
year = 2018



for index, row in js.iterrows():  

    print("Property ID: " + row['property_id'])
    
    avl_day_count = 0
    uvl_day_count = 0
    arr_day_count = 0
    dep_day_count = 0
    
    cal = row['calendar']
    
    month_list = list(cal.keys())
    
    first_date = datetime.date(year, int(month_list[0]), 1)
    
    print("First Date:" + str(first_date))
    
    
    # Create one dictionary with each date?? This should be in the original file!!
# Out:
# Property ID: 9153367
# First month:2
# First Date:2018-02-01
# Property ID: 9076897
# First month:2
# First Date:2018-02-01
# Property ID: 9123458
# First month:2
# First Date:2018-02-01
# Property ID: 9114125
# First month:2
# First Date:2018-02-01
# Property ID: 9063683
# First month:2
# First Date:2018-02-01
# Property ID: 9161490
# First month:2
# First Date:2018-02-01
# Property ID: 9195589
# First month:2
# First Date:2018-02-01
# Property ID: 9167523
# First month:2
# First Date:2018-02-01
# Property ID: 9095729
# First month:2
# First Date:2018-02-01
# Property ID: 9185654
# First month:2
# First Date:2018-02-01
# Property ID: 9179007
# First month:2
# First Date:2018-02-01
# Property ID: 9172704
# First month:2
# First Date:2018-02-01
# Property ID: 9162472
# First month:2
# First Date:2018-02-01
# Property ID: 9222650
# First month:2
# First Date:2018-02-01
# Property ID: 9117434
# First month:2
# First Date:2018-02-01
# Property ID: 9132273
# First month:2
# ...
